# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
df = pd.read_csv('50_startups.csv')

# %%
x = df.iloc[:, [0,2]].values

# %%
def diagram( x ):
    return sch.dendrogram( sch.linkage( x , method='ward') )

dend = diagram(x)
plt.title('Dendrogram')
plt.show()

# %%
# print( set(dend['color_list']) )

# %%
def algo(n, x ):
    hc = AgglomerativeClustering( n_clusters=n, affinity='euclidean', linkage='ward')
    label = hc.fit_predict(x)
    return (hc,label)

# %%
hc, labels = algo(3,x)

# %%
color=['red' , 'yellow' , 'blue' ]
def print_clusters():
    for i in range( 0,3 ):
        plt.scatter( X[labels==i,0], X[labels==i,1], s=125 , color=color[i] )
    plt.show()

# %%
print_clusters()

# %%
x=df.iloc[:, [1,4]].values

# %%
diagram(x)
# Out:
# {'icoord': [[15.0, 15.0, 25.0, 25.0],
#   [5.0, 5.0, 20.0, 20.0],
#   [55.0, 55.0, 65.0, 65.0],
#   [45.0, 45.0, 60.0, 60.0],
#   [35.0, 35.0, 52.5, 52.5],
#   [12.5, 12.5, 43.75, 43.75],
#   [85.0, 85.0, 95.0, 95.0],
#   [125.0, 125.0, 135.0, 135.0],
#   [115.0, 115.0, 130.0, 130.0],
#   [105.0, 105.0, 122.5, 122.5],
#   [90.0, 90.0, 113.75, 113.75],
#   [75.0, 75.0, 101.875, 101.875],
#   [28.125, 28.125, 88.4375, 88.4375],
#   [145.0, 145.0, 155.0, 155.0],
#   [175.0, 175.0, 185.0, 185.0],
#   [165.0, 165.0, 180.0, 180.0],
#   [150.0, 150.0, 172.5, 172.5],
#   [195.0, 195.0, 205.0, 205.0],
#   [215.0, 215.0, 225.0, 225.0],
#   [200.0, 200.0, 220.0, 220.0],
#   [161.25, 161.25, 210.0, 210.0],
#   [235.0, 235.0, 245.0, 245.0],
#   [255.0, 255.0, 265.0, 265.0],
#   [275.0, 275.0, 285.0, 285.0],
#   [260.0, 260.0, 280.0, 280.0],
#   [240.0, 240.0, 270.0, 270.0],
#   [305.0, 305.0, 315.0, 315.0],
#   [295.0, 295.0, 310.0, 310.0],
#   [335.0, 335.0, 345.0, 345.0],
# ...

# %%
hc , labels = algo( 3 , x )

# %%
print_clusters()
